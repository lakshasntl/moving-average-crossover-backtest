# %%
pip install pandas yfinance matplotlib seaborn notebook
# Out:
# Requirement already satisfied: pandas in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: yfinance in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (0.2.65)
# Requirement already satisfied: matplotlib in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (3.8.3)
# Requirement already satisfied: seaborn in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: notebook in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (6.4.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: numpy>=1.18.5 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (4.3.8)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (4.13.4)
# Requirement already satisfied: curl_cffi>=0.7 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (0.12.0)
# Requirement already satisfied: protobuf>=3.19.0 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (6.31.1)
# Requirement already satisfied: websockets>=13.0 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=8 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (6.3.0)
# Requirement already satisfied: jinja2 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from notebook) (2.11.3)
# Requirement already satisfied: tornado>=6.1 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from notebook) (6.1)
# Requirement already satisfied: pyzmq>=17 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from notebook) (22.3.0)
# Requirement already satisfied: argon2-cffi in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from notebook) (20.1.0)
# Requirement already satisfied: ipython-genutils in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from notebook) (0.2.0)
# Requirement already satisfied: traitlets>=4.2.1 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from notebook) (5.14.3)
# Requirement already satisfied: jupyter-core>=4.6.1 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from notebook) (4.9.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from notebook) (7.1.2)
# Requirement already satisfied: nbformat in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from notebook) (5.1.3)
# Requirement already satisfied: nbconvert in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from notebook) (6.3.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from notebook) (1.5.1)
# Requirement already satisfied: ipykernel in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from notebook) (6.4.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from notebook) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from notebook) (0.13.1)
# Requirement already satisfied: prometheus-client in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from notebook) (0.13.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.14.1)
# Requirement already satisfied: cffi>=1.12.0 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from curl_cffi>=0.7->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2024.2.2 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from curl_cffi>=0.7->yfinance) (2024.2.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.7.0)
# Requirement already satisfied: entrypoints in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client>=5.3.4->notebook) (0.3)
# Requirement already satisfied: six>=1.5 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.31->yfinance) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.31->yfinance) (1.26.8)
# Requirement already satisfied: ptyprocess in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from terminado>=0.8.3->notebook) (0.7.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->notebook) (1.5.1)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->notebook) (7.31.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->notebook) (0.1.2)
# Requirement already satisfied: appnope in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->notebook) (0.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from jinja2->notebook) (2.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook) (0.8.4)
# Requirement already satisfied: pygments>=2.4.1 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook) (2.11.2)
# Requirement already satisfied: jupyterlab-pygments in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook) (0.1.2)
# Requirement already satisfied: bleach in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook) (1.5.0)
# Requirement already satisfied: testpath in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook) (0.5.0)
# Requirement already satisfied: defusedxml in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook) (0.5.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from nbformat->notebook) (3.2.0)
# Requirement already satisfied: pycparser in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: setuptools>=18.5 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook) (58.0.4)
# Requirement already satisfied: jedi>=0.16 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook) (0.18.1)
# Requirement already satisfied: decorator in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook) (5.1.1)
# Requirement already satisfied: pickleshare in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook) (3.0.20)
# Requirement already satisfied: backcall in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook) (4.8.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook) (21.4.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook) (0.18.0)
# Requirement already satisfied: async-generator in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook) (1.10)
# Requirement already satisfied: webencodings in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel->notebook) (0.8.3)
# Requirement already satisfied: wcwidth in /Users/lakshasenthilkumar/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel->notebook) (0.2.5)
#
# [notice] A new release of pip is available: 24.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Step 1: Import Libraries
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Download Historical Data
ticker = "NVDA"  # NVIDIA
start_date = "2015-01-01"
end_date = "2024-12-31"

df = yf.download(ticker, start=start_date, end=end_date, auto_adjust=True)
df.head()

#This data shows the adjusted stock prices, 
#which have been historically adjusted downward
#We are using historical data because this project uses backtesting to see how
#this stock would have preformed in the past
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open     Volume
# Ticker          NVDA      NVDA      NVDA      NVDA       NVDA
# Date
# 2015-01-02  0.483066  0.486665  0.475386  0.483066  113680000
# 2015-01-05  0.474907  0.484505  0.472747  0.483066  197952000
# 2015-01-06  0.460508  0.476106  0.460028  0.475626  197764000
# 2015-01-07  0.459308  0.467947  0.457868  0.463868  321808000
# 2015-01-08  0.476586  0.479466  0.464348  0.464588  283780000

# %%
df.head()
df.isnull().sum()

plt.figure(figsize=(12,6))
plt.plot(df["Close"], label="Close Price")
plt.title(f"{ticker} Close Price")
plt.xlabel("Date")
plt.ylabel("Price ($)")
plt.legend()
plt.show()

# %%
# Calculates the averages of the last 50 days for each closing price
df['MA_50'] = df['Close'].rolling(window=50).mean() 
# this is long term
df['MA_200'] = df['Close'].rolling(window=200).mean()
# this is short term

#When these two averages cross over, it signals a change in the trend
#A short term MA crossing ABOVE a long term MA means its time to BUY
#A short term MA crossing BELOW a long term MA means its time to SELL

# Check the last few rows
df[['Close', 'MA_50', 'MA_200']].tail()
# Out:
# Price            Close       MA_50      MA_200
# Ticker            NVDA
# Date
# 2024-12-23  139.647446  139.688259  116.606688
# 2024-12-24  140.197372  139.731442  116.878975
# 2024-12-26  139.907410  139.898196  117.119130
# 2024-12-27  136.987885  139.924179  117.349810
# 2024-12-30  137.467804  139.935566  117.597604

# %%
# Initialize Signal column
df['Signal'] = 0

# Set Signal to 1 when short-term MA > long-term MA because its time to INVEST
df.loc[df['MA_50'] > df['MA_200'], 'Signal'] = 1

# Optional: Fill any NaNs (not strictly needed here but safe)
df['Signal'] = df['Signal'].fillna(0)

#This sets the rule to signal when to buy and when not to buy

# %%
# Position: 1 = in the market, 0 = out
df['Position'] = df['Signal'].shift(1)  # Shift signal so we buy *next* day
df['Position'] = df['Position'].fillna(0)

# %%
plt.figure(figsize=(14, 7))
plt.plot(df['Close'], label='Close Price', alpha=0.5)
plt.plot(df['MA_50'], label='50-day MA', linewidth=1.2)
plt.plot(df['MA_200'], label='200-day MA', linewidth=1.2)

# Plot buy signals
buy_signals = df[(df['Position'] == 1) & (df['Position'].shift(1) == 0)]
plt.scatter(buy_signals.index, df.loc[buy_signals.index]['Close'], marker='^', color='green', label='Buy Signal', s=100)

# Plot sell signals
sell_signals = df[(df['Position'] == 0) & (df['Position'].shift(1) == 1)]
plt.scatter(sell_signals.index, df.loc[sell_signals.index]['Close'], marker='v', color='red', label='Sell Signal', s=100)

plt.title(f'{ticker} Strategy Buy/Sell Signals')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# Daily returns from closing prices
df['Daily_Return'] = df['Close'].pct_change()
df['Daily_Return']
#Shows how volatile a stock is day to day
# Out:
# Date
# 2015-01-02         NaN
# 2015-01-05   -0.016890
# 2015-01-06   -0.030318
# 2015-01-07   -0.002606
# 2015-01-08    0.037617
#                 ...
# 2024-12-23    0.036897
# 2024-12-24    0.003938
# 2024-12-26   -0.002068
# 2024-12-27   -0.020868
# 2024-12-30    0.003503
# Name: Daily_Return, Length: 2515, dtype: float64

# %%
# Strategy returns = return only when you're in the market
df['Strategy_Return'] = df['Daily_Return'] * df['Position']
df['Strategy_Return']
#shows how well your signals translate to profit and compare when you're 
#active vs passive income
#Your return on a given day only if you were holding the stock, based on your strategy
# Out:
# Date
# 2015-01-02         NaN
# 2015-01-05   -0.000000
# 2015-01-06   -0.000000
# 2015-01-07   -0.000000
# 2015-01-08    0.000000
#                 ...
# 2024-12-23    0.036897
# 2024-12-24    0.003938
# 2024-12-26   -0.002068
# 2024-12-27   -0.020868
# 2024-12-30    0.003503
# Name: Strategy_Return, Length: 2515, dtype: float64

# %%
df['Cumulative_Market_Returns'] = (1 + df['Daily_Return']).cumprod()
df['Cumulative_Strategy_Returns'] = (1 + df['Strategy_Return']).cumprod()

#This is the Equity curve - how the portfolio grows
#you're growth over time if you reinvest
#is this strategy worth holding?

# %%
df['Cumulative_Strategy_Returns']
# Out:
# Date
# 2015-01-02           NaN
# 2015-01-05      1.000000
# 2015-01-06      1.000000
# 2015-01-07      1.000000
# 2015-01-08      1.000000
#                  ...
# 2024-12-23    266.258773
# 2024-12-24    267.307291
# 2024-12-26    266.754433
# 2024-12-27    261.187921
# 2024-12-30    262.102959
# Name: Cumulative_Strategy_Returns, Length: 2515, dtype: float64

# %%
df['Cumulative_Market_Returns']
# Out:
# Date
# 2015-01-02           NaN
# 2015-01-05      0.983110
# 2015-01-06      0.953303
# 2015-01-07      0.950820
# 2015-01-08      0.986587
#                  ...
# 2024-12-23    289.085898
# 2024-12-24    290.224308
# 2024-12-26    289.624053
# 2024-12-27    283.580308
# 2024-12-30    284.573795
# Name: Cumulative_Market_Returns, Length: 2515, dtype: float64

# %%
plt.figure(figsize=(14, 7))
plt.plot(df['Cumulative_Market_Returns'], label='Buy & Hold', linestyle='--')
plt.plot(df['Cumulative_Strategy_Returns'], label='MA Crossover Strategy', linewidth=2)
plt.title(f'Cumulative Returns: {ticker}')
plt.xlabel('Date')
plt.ylabel('Portfolio Value (Normalized)')
plt.legend()
plt.show()

# %%
# Total Return
total_strategy_return = df['Cumulative_Strategy_Returns'].iloc[-1] - 1
total_market_return = df['Cumulative_Market_Returns'].iloc[-1] - 1

print(f"Strategy Total Return: {total_strategy_return:.2%}")
print(f"Market Total Return: {total_market_return:.2%}")
# Out:
# Strategy Total Return: 26110.30%
# Market Total Return: 28357.38%

# %%
strategy_returns = df['Strategy_Return'].dropna()
market_returns = df['Daily_Return'].dropna()

sharpe_strategy = (strategy_returns.mean() / strategy_returns.std()) * (252 ** 0.5)
sharpe_market = (market_returns.mean() / market_returns.std()) * (252 ** 0.5)

print(f"Sharpe Ratio (Strategy): {sharpe_strategy:.2f}")
print(f"Sharpe Ratio (Market): {sharpe_market:.2f}")

#compares different strategy across difeferent risk levels
#A measure of risk-adjusted return
#It tells you how much return you’re getting for each unit of risk
# Out:
# Sharpe Ratio (Strategy): 1.54
# Sharpe Ratio (Market): 1.41
